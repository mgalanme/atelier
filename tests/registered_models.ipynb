# %%
from databricks.sdk import WorkspaceClient

client = WorkspaceClient()

# Listar todos los modelos registrados en Unity Catalog
for model in client.registered_models.list(catalog_name="atelier", schema_name="gold"):
    print(f"Model: {model.name}")
