# %%
from databricks.sdk import WorkspaceClient

client = WorkspaceClient()

test_input = [
    {
        "concept": "A sustainable winter collection inspired by Arctic landscapes",
        "target_audience": "Young professionals, eco-conscious, urban lifestyle",
    }
]

response = client.serving_endpoints.query(
    name="atelier-storytelling-agent", dataframe_records=test_input
)

print("✅ Respuesta del agente:")
print(response.predictions)
